# %% [raw]
# ---
# title: "Quarto Basics"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %% [markdown]
# # Creating a database with a list of the issue of new land title deeds in Kenya.
#
# This is a project scraping HTML pages of weekly Kenya Gazette notices starting from 2010 in order to retrieve and categorise land-related notices. The result is a database with more than 200,000 rows of land-related notice entries.
#
#
# ### Getting the Data
# * [Weekly Kenya Gazette notices](http://kenyalaw.org/kenya_gazette/gazette)
# * [Districts, areas and population](http://www.statoids.com/yke.html)
# * [Shapefile of Kenyan provinces](https://www.igismap.com/kenya-shapefile-download-boundary-line-administrative-state-and-polygon/)
#
# ## The Kenya Gazette
#
# ## This is what the home page of the Kenya Gazette looks like
#
# ![Home Page](screenshot_of_home_page.png)
#
# ## This is what the landing page for one year of gazette notices looks like
#
# ![Landing Page for 2022](screenshot_of_2022_page.png)

# %% [markdown]
# # Setting Everything Up

# %%
#import the file from the web
import requests
from bs4 import BeautifulSoup
import pandas as pd
from unicodedata import normalize
import re

# I can give a number or use None to remove maximum ceiling & display all columns
pd.options.display.max_columns = None

# I want to be able to see the entire narrative, so remove the maximum width for each column
pd.options.display.max_colwidth = None



from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry


#To resolve retry http error
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# %% [markdown]
# ### Outlining the years of Interest

# %%
#From 2010 to 2020
#Weekly issues

#Every url for a year's worth of gazette notices starts with this url_year_base below

url_year_base="http://kenyalaw.org/kenya_gazette/gazette/year/"

#I am trying to scrape for the years with htmls, that is 2010 to 2020
#Getting the range from 2010 to 2021 so 2020 can be included, then setting it into a list

years=list(range(2010,2021))
years
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %% [markdown]
# # Getting the urls for each year

# %%
#to get each url for each year containing a list of the year's gazette notices

year_link_dict_list=[]

for year in years:
    year_link_dict={}
    url_year=url_year_base+str(year)
#     print(url_year)
    year_link_dict['year']=year
    year_link_dict['url_year']=url_year
    year_link_dict_list.append(year_link_dict)
    
url_year_links = [x['url_year'] for x in year_link_dict_list]

# %%
#To see a list of dictionaries each with a year and its url
year_link_dict_list
# Out:
# [{'year': 2010,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2010'},
#  {'year': 2011,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2011'},
#  {'year': 2012,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2012'},
#  {'year': 2013,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2013'},
#  {'year': 2014,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2014'},
#  {'year': 2015,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2015'},
#  {'year': 2016,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2016'},
#  {'year': 2017,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2017'},
#  {'year': 2018,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2018'},
#  {'year': 2019,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2019'},
#  {'year': 2020,
#   'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2020'}]

# %% [markdown]
# # Getting the HTML content on each year's page for all gazette notices within it.
#
# ### Here, as a list of dictionaries, I get the following information:
# * year
# * url for the year
# * url for each gazette notice within the year.

# %%
    
for year_link_dict in year_link_dict_list:
    print("$$$$$$$$$$$$")
    url_year_link=year_link_dict['url_year']
    print(url_year_link)
    year_raw_html = requests.get(url_year_link).content
    print(type(year_raw_html))
    
    #assign year_urls_soup_doc as the doc holding parsed html 
    #learn type of year_urls_soup_doc
    year_urls_soup_doc = BeautifulSoup(year_raw_html, "html.parser")
    print(type(year_urls_soup_doc))
    print("________")
    
    
    #These are the links on the page for all gazette notices
    links_within_year=year_urls_soup_doc.select('#content')

    #Both weekly and special gazette notices sections
    sections_within_year = str(links_within_year).split('<p>') 
    
    #To get weekly issues only use sections_within_year[1]
    #Then split it by tr to get each entry of a gazette notice
    sections_within_year[1].split('<tr>')
    weekly_section=sections_within_year[1]
    weekly_section_entries=weekly_section.split('<tr>')
    
    
    link_href_list=[]

    for link_within_section in weekly_section_entries:
        try:
            link_href=link_within_section.split('<td>')[2].split('"')[1]
#             print(link_href)
#             print("______")
            link_href_list.append(link_href)
            year_link_dict['gazette_links']=link_href_list

        except:
            pass

#     print(year_link_dict)
    
print(year_link_dict_list[0])
# Out:
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2010
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2011
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2012
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2013
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2014
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2015
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2016
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2017
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2018
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2019
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# $$$$$$$$$$$$
# http://kenyalaw.org/kenya_gazette/gazette/year/2020
# <class 'bytes'>
# <class 'bs4.BeautifulSoup'>
# ________
# [{'year': 2010, 'url_year': 'http://kenyalaw.org/kenya_gazette/gazette/year/2010', 'gazette_links': ['http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjc0/Vol. CXII - No. 133/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcy/Vol. CXII - No. 131/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcw/Vol. CXII - No. 128/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/MjY5/Vol. CXII - No. 125/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/MjY4/Vol. CXII - No. 123/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/MjY3/Vol. CXII - No. 120/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/MjYx/Vol. CXII - No. 114/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/MjU1/Vol. CXII - No. 108/', 'http://kenyalaw.org/kenya_gazette/gazette/volume/M
, http://kenyalaw.org/kenya_gazette/gazette/volume/ODU3/Vol. CXVI-No. 29/, http://kenyalaw.org/kenya_gazette/gazette/volume/ODQ3/Vol. CXVI-No. 25/, http://kenyalaw.org/kenya_gazette/gazette/volume/ODQx/Vol. CXVI-No. 22/, http://kenyalaw.org/kenya_gazette/gazette/volume/ODQw/Vol. CXVI-No. 18/, http://kenyalaw.org/kenya_ ...

# %% [markdown]
# ### Explode this so that each html for a weekly gazette notice gets its own row

# %%
df_links = df_links_list.explode("gazette_links").reset_index()
df_links.head()
# Out:
#    index  year                                             url_year  \
# 0      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 1      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 2      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 3      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 4      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
#
#                                                                 gazette_links
# 0  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 1  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjc0/Vol. CXII - No. 133/
# 2  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcy/Vol. CXII - No. 131/
# 3  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcw/Vol. CXII - No. 128/
# 4  http://kenyalaw.org/kenya_gazette/gazette/volume/MjY5/Vol. CXII - No. 125/

# %%
#save the result to a csv file
df_links.to_csv("titles_links.csv")

# %% [markdown]
# ## This is what the one section of land-related notices in the Weekly Kenya Gazette looks like
#
# ![One section of land-related notices](one_section_of_land_notices_in_weekly_gazette.png)

# %% [markdown]
# # Create a function that scrapes a url for a gazette notice to extract the following information:
#
# * volume number: volume_num
# * volume date: volume_date
# * volume url: volume_url
# * title of notice's number: notice_num_title
# * title of notice's act: notice_act_title
# * notice's capital and section: notice_num_year
# * notice's subtitle: notice_sub_title
# * notice's full body of info: notice_body
# * specific notice's date: notice_date
# * name of notice's registrar: notice_registrar_name
# * number and location of notice: notice_num_loc
# * notice's location: notice_loc

# %%
def scrape_url(my_url):
    try: 
        raw_html = requests.get(my_url).content

        #assign soup_doc as the doc holding parsed html 
        #learn type of soup_doc
        soup_doc = BeautifulSoup(raw_html, "html.parser")

        #Finding volume number to keep track of what data is from what source in larger csv
        
            
        

        # creating a list of all divs with id starting with GAZETTE NOTICE
        list_all_divs= [elem.parent.parent for elem in soup_doc.find_all("em", text=re.compile("(Land Registrar|Registrar of Land|Registrar of Titles)", re.IGNORECASE))]
        #The parent of p is a div
        #print("Found", len(list_all_divs), "potentials")
        #create function for making a dictionary out of each entry within the list of all divs
        def class_to_dictionary(list_of_items):
            #initialise keys of dictionary
            dict_titles=['volume_num',
                     'volume_date',
                     'volume_url',
                     'notice_num_title',
                     'notice_act_title',
                     'notice_num_year',
                     'notice_sub_title',
                     'notice_body',
                     'notice_date',
                     'notice_registrar_name',
                     'notice_num_loc',
                     'notice_loc']
            
            #initialise empty list which will contain all new notice entries
            all_new_notice_entries=[]
            
            #For one entry within the list of items which is a variable you will pass in the function
            #list_of_items will usually be the large capsules containing gazette entries
            #mostly for the ones I have seen there are two such capsules among these that have land registration act entries
            
            for one_item in list_of_items:
                
                
                #if the words LAND REGISTRATION ACT or Land Registrar appear in the text
                if "LAND REGISTRATION ACT" in one_item.text or "Land Registrar" in one_item.text:

                    #Then split one_item at the <hr/> point
                    entry_deets = str(one_item).split('<hr/>') 
                    
                    #now entry_deets is a list of notices within the capsule
                    for entry_deet in entry_deets:
                        
                        #one entry_deet is a notice within the capsule
                        
                        #initialise a list which I plan to zip to dict_titles to make a dictionary
                        entry_deet_full_list=[]
                        
                        #since I changed to string to split on hr
                        #I need to return the content to beautiful soup classes

                        entry_deet_soup = BeautifulSoup(entry_deet, "html.parser")
                        
                        #now make a list of all p's within the gazette notice
                        entry_deet_paragraphs = entry_deet_soup.find_all('p')
                        
                        #When converting to text I kept getting Xa0
                        # Normalize unicode data like this
        #               # normalize("NFKD", x.text)
                        # https://stackoverflow.com/questions/10993612/how-to-remove-xa0-from-string-in-python
                        entry_deet_paragraphs = [normalize("NFKD", x.text) for x in entry_deet_paragraphs if x.text.strip()!='']
                        if len(entry_deet_paragraphs) == 0:
                            continue


                        #Introducing number, date and url
                        #Then the rest comes from 
                        volume_num=soup_doc.select(".gazette-content #content div")[2].text
                        volume_date=soup_doc.select(".gazette-content #content div")[3].text
                        volume_url=my_url
                        notice_num_title=entry_deet_paragraphs[0]
                        notice_act_title=entry_deet_paragraphs[1]
                        notice_num_year=entry_deet_paragraphs[2]
                        notice_sub_title=entry_deet_paragraphs[3]
                        notice_body=entry_deet_paragraphs[4]
                        notice_date=entry_deet_paragraphs[5]
                        notice_registrar_name=entry_deet_paragraphs[6]
                        notice_num_loc=entry_deet_paragraphs[7]
                        try:
                            notice_loc=(entry_deet_soup.find_all('p')[-1]).text.split(',')[1]
                        except:
                            notice_loc="Na"
                        
                        entry_deet_full_list.append(volume_num)
                        entry_deet_full_list.append(volume_date)
                        entry_deet_full_list.append(volume_url)
                        entry_deet_full_list.append(notice_num_title)
                        entry_deet_full_list.append(notice_act_title)
                        entry_deet_full_list.append(notice_num_year)
                        entry_deet_full_list.append(notice_sub_title)
                        entry_deet_full_list.append(notice_body)
                        entry_deet_full_list.append(notice_date)
                        entry_deet_full_list.append(notice_registrar_name)
                        entry_deet_full_list.append(notice_num_loc)
                        entry_deet_full_list.append(notice_loc)



        #             #     print(new_deet_list)

                        first_rep = dict(zip(dict_titles,entry_deet_full_list))
        #         #         print(first_rep)

        #         #         print("######")

                        all_new_notice_entries.append(first_rep)
            return all_new_notice_entries


        data = class_to_dictionary(list_all_divs)
        return data
    except Exception as e:
#         raise e
        pass

# %% [markdown]
# #### Example scrape for one url using the function created

# %%
#read csv
#loop through links
# my_url = "http://kenyalaw.org/kenya_gazette/gazette/volume/MjIzMA--/Vol.CXXII-No.199/"

#Get the list of dictionaries
data = scrape_url("http://kenyalaw.org/kenya_gazette/gazette/volume/MjIzMA--/Vol.CXXII-No.199/")
data
#convert to a dataframe
# pd.DataFrame(data)

#save the resulting large dataframe to csv

# %%
scrape_url('http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/')
# Out:
# [{'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16759',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 35)',
#   'notice_sub_title': 'Issue of a New Certificate of Lease',
#   'notice_body': 'WHEREAS Francis Meso, of P.O. Box 52540, Nairobi in the Republic of Kenya, is registered as proprietor in leasehold interests of that piece of land containing 0.0141 hectare or thereabouts, situate in the city of Nairobi, registered under title No. Nairobi Block 93/686, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new certificate of lease provided that no objection has been received within that period.',
#   'notice_date': 'Dated the 31st December, 2010.',
#   'notice_registrar_name': 'B. K. LEITICH,',
#   'notice_num_loc': 'Land Registrar, Nairobi.',
#   'notice_loc': ' Nairobi.'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16760',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 35)',
#   'notice_sub_title': 'Issue of a New Land Title Deed',
#   'notice_body': 'WHEREAS Milcah Wangui Wambura, of P.O. Box 42660, Nairobi in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing
',
#   'notice_num_loc': 'Land Registrar,',
#   'notice_loc': 'Na'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16795',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 35)',
#   'notice_sub_title': 'Issue of a New Land Title Deed',
#   'notice_body': 'WHEREAS Wangui Ndachi Gituhu, of P.O. Box 1064, Nyahururu in the Republic of Kenya, is registered as proprietor in absolute ownership interest of those pieces of land containing 2.73 and 0.12 hectare or thereabouts, situate in the district of Laikipia, registered under title Nos. Narok/Mutara Block 1/57 and Narok/Mutara South Block 1/1201, respectively, and whereas sufficient evidence has been adduced to show that the land title deeds issued thereof have been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue new land title deeds provided that no objection has been received within that period.',
#   'notice_date': 'Dated the 31st December, 2010.',
#   'notice_registrar_name': 'L. K. WARACHI,',
#   'notice_num_loc': 'Land Registrar,',
#   'notice_loc': 'Na'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16796',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 35)',
#   'notice_sub_title': 'Issue of a New Land Title Deed',
#   'notice_body': 'WHEREAS David Kingori Waweru, is registered as proprietor in absolute ownership interest of those pieces of land containing 4.15 and 0.405 hectare or thereabouts, situate in the district of Laikipia, registered under title Nos. Laikipia/Nyahururu/359 and 2703, respectively, and whereas sufficient evidence has been adduced to show that the land title deeds issued thereof have been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue new land title deeds provided that no objection has been received within that period.',
#   'notice_date': 'Dated the 31st December, 2010.',
#   'notice_registrar_name': 'L. K. WARACHI,',
#   'notice_num_loc': 'Land Registrar,',
#   'notice_loc': 'Na'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16797',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 35)',
#   'notice_sub_title': 'Issue of a New Land Title Deed',
#   'notice_body': 'WHEREAS John Masaka Mwangecho, of P.O. Box 90540, Mombasa in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land situate in the district of Kwale, registered under title No. Kwale/Mnanasini/570, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof have been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.',
#   'notice_date': 'Dated the 31st December, 2010.',
#   'notice_registrar_name': 'J. K. KOSKEI,',
#   'notice_num_loc': 'Land Registrar,',
#   'notice_loc': 'Na'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16799',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 33)',
#   'notice_sub_title': 'Registration of Instrument',
#   'notice_body': 'WHEREAS Jeremiah Murithi Mwirichia (deceased), is registered proprietor of that piece of land known as Nkuene/Kathera/1239, situate in the district of Meru, and whereas the High Court of Kenya in succession cause No. 236 of 2005, has issued grant of letters of administration and certificate of confirmation of grant in favour of Joseph Mwebia Jeremiah, and whereas said court has executed an application to be registered as proprietor by transmission RL. 19, and whereas the land title deed in respect of the said piece of land registered in the name of the Jeremiah Murithi Mwirichia is lost, notice is given that after the expiration of thirty (30) days from the date hereof, provided no valid objection has been received within that period, I intend to dispense with the production of the said land title deed and proceed with the registration of the said application to be registered as proprietor by transmission RL. 19 in the name of Joseph Mwebia Jeremiah, and upon such registration the land title deed issued earlier to the said Jeremiah Murithi Mwirichia (deceased), shall be deemed to be cancelled and of no effect.',
#   'notice_date': 'Dated the 31st December, 2010.',
#   'notice_registrar_name': 'H. S. W. MUSUMIAH,',
#   'notice_num_loc': 'Land Registrar,',
#   'notice_loc': 'Na'},
#  {'volume_num': 'Vol. CXII - No. 135',
#   'volume_date': 'NAIROBI, \n\t\t    \t31 December,2010 ',
#   'volume_url': 'http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/',
#   'notice_num_title': 'Gazette Notice No. 16800',
#   'notice_act_title': 'THE REGISTERED LAND ACT',
#   'notice_num_year': '(Cap. 300, section 33)',
#   'notice_sub_title': 'Registration of Instrument',
#   'notice_body': 'WHEREAS Moses Mbothu Chaure (deceased), of P.O. Box 327, Eldoret in the Republic of Kenya, is registered proprietor of that piece of land known as Tulwet/Tulwet Block 3 (Rironi)/219, situate in the district of Uasin Gishu, and whereas the High Court of Kenya at',
#   'notice_date': 'Eldoret, in succession cause No. 149 of 2009, has issued grant and confirmation letters to Samuel Ndungu Bothu, of P.O. Box 1751, Eldoret, and whereas all efforts made to recover the land title deed and be surrendered to the land registrar for cancellation have failed, notice is given that after the expiration of thirty (30) days from the date hereof, provided no valid objection has been received within that period, I intend to dispense with the production of the said land title deed and proceed with the registration of the administration letter to Samuel Ndungu Bothu, and upon such registration the land title deed issued earlier to the said Moses Mbothu Chaure (deceased), shall be deemed to be cancelled and of no effect.',
#   'notice_registrar_name': 'Dated the 31st December, 2010.',
#   'notice_num_loc': 'W. K. SIRMA,',
#   'notice_loc': 'Na'}]

# %% [markdown]
# # Use the function created to now scrape through all gazette links which were earlier scraped and saved into the df_links gazette link
# Save it into a large list and then create a dataframe from it

# %%
data_list = []

for gazette_link in df_links.gazette_links:
    try:
        print(gazette_link)
        my_url = gazette_link

        #Get the list of dictionaries
        data = scrape_url(my_url)
        print(len(data))
        if data:
            data_list.append(data)
    except:
        pass
        
# save the resulting large dataframe to csv

data_list_flat = [item for sublist in data_list for item in sublist]
df=pd.DataFrame(data_list_flat)
df.shape
# Out:
# http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 32
# http://kenyalaw.org/kenya_gazette/gazette/volume/Mjc0/Vol. CXII - No. 133/
# 32
# http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcy/Vol. CXII - No. 131/
# 58
# http://kenyalaw.org/kenya_gazette/gazette/volume/Mjcw/Vol. CXII - No. 128/
# 46
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjY5/Vol. CXII - No. 125/
# 24
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjY4/Vol. CXII - No. 123/
# 30
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjY3/Vol. CXII - No. 120/
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjYx/Vol. CXII - No. 114/
# 61
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjU1/Vol. CXII - No. 108/
# 35
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjU2/Vol. CXII - No. 109/
# 0
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjUy/Vol. CXII - No. 105/
# 36
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjQ4/Vol. CXII - No. 101/
# 45
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjQ1/Vol. CXII - No. 99/
# 42
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjQx/Vol. CXII - No. 95/
# 61
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjM4/Vol. CXII - No. 93/
# 49
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjM2/Vol. CXII - No. 91/
# 55
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjM1/Vol. CXII - No. 90/
# 21
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjMz/Vol. CXII - No. 88/
# 54
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjMx/Vol. CXII - No. 85/
# 37
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjI5/Vol. CXII - No. 83/
# 19
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjI1/Vol. CXII - No. 79/
# 56
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjIz/Vol. CXII - No. 77/
# 37
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjE5/Vol. CXII - No. 73/
# 39
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTk3/Vol. CXII - No. 70/
# 42
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTk4/Vol. CXII - No. 69/
# 24
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTk5/Vol. CXII - No. 67/
# 34
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjAx/Vol. CXII - No. 65/
# 59
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjE2/Vol. CXII - No. 62/
# 32
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjA1/Vol. CXII - No. 61/
# 52
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjA3/Vol. CXII - No. 58/
# 37
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjA4/Vol. CXII - No. 56/
# 24
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjA5/Vol. CXII - No. 55/
# 57
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjEx/Vol. CXII - No. 53/
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTky/Vol. CXII - No. 49/
# 30
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTg5/Vol. CXII - No. 46/
# 74
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTg3/Vol. CXII - No. 44/
# 73
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjE1/Vol. CXII - No. 40/
# 66
# http://kenyalaw.org/kenya_gazette/gazette/volume/MjE0/Vol. CXII - No. 38/
# 28
# http://kenyalaw.org/kenya_gazette/gazette/volume/Mjc3/Vol. CXII - No. 37/
# 0
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTc4/Vol. CXII - No. 34/
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTcz/Vol. CXII - No. 30/
# 32
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTcx/Vol. CXII - No. 28/
# 53
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTY4/Vol. CXII - No. 24/
# 23
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTY2/Vol. CXII - No. 22/
# 0
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTY1/Vol. CXII - No. 21/
# 0
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTU5/Vol. CXII - No. 18/
# 41
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTU1/Vol. CXII - No. 15/
# 35
# http://kenyalaw.org/kenya_gazette/gazette/volume/MTU3/Vol. CXII - No. 16/
# 0
# http://kenyalaw.org/kenya_gazette/gazette/volume/MT
http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
#
#            notice_num_title         notice_act_title         notice_num_year  \
# 0  Gazette Notice No. 16759  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 1  Gazette Notice No. 16760  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 2  Gazette Notice No. 16761  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 3  Gazette Notice No. 16762  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 4  Gazette Notice No. 16763  THE REGISTERED LAND ACT  (Cap. 300, section 35)
#
#                       notice_sub_title  \
# 0  Issue of a New Certificate of Lease
# 1       Issue of a New Land Title Deed
# 2       Issue of a New Land Title Deed
# 3       Issue of a New Land Title Deed
# 4       Issue of a New Land Title Deed
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         notice_body  \
# 0                       WHEREAS Francis Meso, of P.O. Box 52540, Nairobi in the Republic of Kenya, is registered as proprietor in leasehold interests of that piece of land containing 0.0141 hectare or thereabouts, situate in the city of Nairobi, registered under title No. Nairobi Block 93/686, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new certificate of lease provided that no objection has been received within that period.
# 1                WHEREAS Milcah Wangui Wambura, of P.O. Box 42660, Nairobi in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 7.6 acres or thereabout, situate in the city of Nairobi, registered under title No. Dagoretti/Mutuini/309, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 2                                                   WHEREAS Joseph Muchiri Kenja, is registered as proprietor in absolute ownership interest of that piece of land containing 0.045 hectare or thereabouts, situate in the district of Nakuru, registered under title No. Nakuru/Municipality Block 22/607, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 3          WHEREAS Charles Kangangi, of P.O. Box 11, Subukia in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 1.445 hectares or thereabout, situate in the district of Nakuru, registered under title No. Subukia/Subukia Block 3/113, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 4  WHEREAS John Njenga Kariuki, of P.O. Box 14938, Nakuru in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 0.047 hectare or thereabouts, situate in the district of Nakuru, registered under title No. Kiambogo/Kiambogo Block 2/6772, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
#
#                       notice_date notice_registrar_name  \
# 0  Dated the 31st December, 2010.        B. K. LEITICH,
# 1  Dated the 31st December, 2010.        B. K. LEITICH,
# 2  Dated the 31st December, 2010.         J. M. MWAURA,
# 3  Dated the 31st December, 2010.         J. M. MWAURA,
# 4  Dated the 31st December, 2010.             M. SUNGU,
#
#              notice_num_loc notice_loc
# 0  Land Registrar, Nairobi.   Nairobi.
# 1  Land Registrar, Nairobi.   Nairobi.
# 2           Land Registrar,         Na
# 3           Land Registrar,         Na
# 4           Land Registrar,         Na

# %%
df_large.shape
# Out:
# (230428, 17)

# %%
df_large.to_csv("titles_new_df_large.csv")

# %% [markdown]
# # Read data on Districts, Population and Area and merge it to the location information in the dataframe
#
# This data is important so that I can normalise the data on population but also so that I can get the code that I can use to group the data by provinces

# %%
df_districts=pd.read_excel('/Users/ivynyayieka/Downloads/districts.xlsx')
df_districts.head()
# Out:
#   District      HASC  Cod  Population  Area(km.²)   Capital
# 0  Baringo  KE.RV.BA  701      264978      8646.0  Kabarnet
# 1    Bomet  KE.RV.BO  702      382794      1882.0     Bomet
# 2    Bondo  KE.NY.BO  611      238780       987.0     Bondo
# 3  Bungoma  KE.WE.BN  801      876491      2069.0   Bungoma
# 4    Buret  KE.RV.BU  718      316882       955.0    Litein

# %%
df_districts['district_named']=df_districts.District+" District"
df_districts.head()
# Out:
#   District      HASC  Cod  Population  Area(km.²)   Capital    district_named
# 0  Baringo  KE.RV.BA  701      264978      8646.0  Kabarnet  Baringo District
# 1    Bomet  KE.RV.BO  702      382794      1882.0     Bomet    Bomet District
# 2    Bondo  KE.NY.BO  611      238780       987.0     Bondo    Bondo District
# 3  Bungoma  KE.WE.BN  801      876491      2069.0   Bungoma  Bungoma District
# 4    Buret  KE.RV.BU  718      316882       955.0    Litein    Buret District

# %% [markdown]
# ### Clean up the districts' information in the dataframe to make it possible to join with districts dataframe

# %%
df_large.notice_loc=df_large.notice_loc.str.replace(".", "")
df_large.notice_loc=df_large.notice_loc.str.replace("Districts", "")
df_large.notice_loc=df_large.notice_loc.str.replace("District", "")
df_large.notice_loc=df_large.notice_loc.str.strip()
df_large.notice_loc.unique()
# Out:
# /var/folders/hr/dj9m37jd2dx8mrzg37j_03040000gn/T/ipykernel_21035/299477449.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_large.notice_loc=df_large.notice_loc.str.replace(".", "")
# array(['Nairobi', 'Na', 'Eldoret', 'Kiambu', 'Kirinyaga', 'Thika', 'Meru',
#        'Machakos', 'Kitui', 'Kajiado', 'Mombasa', 'Nakuru', 'Embu', nan,
#        'Nyeri', 'Laikipia', 'Siaya', 'Kitale', '', 'Naivasha', 'Mbeere',
#        'Kericho/Bureti', 'Kilifi/Kaloleni/Malindi/Ganze', 'Uasin-Gishu',
#        'Narok North', 'Vihiga', 'Kuria', 'Busia/Teso', 'Kwale Distict',
#        'Kakamega', 'Lamu', 'Bungoma', 'Trans Nzoia', 'Makueni',
#        'Rachuonyo', 'Kwale', 'Kisumu', 'Bondo', 'Uasin Gishu', 'Nyando',
#        'Migori/Rongo', 'Busia', 'Busia (K)', 'Nyandarua/Samburu',
#        'Eldoretv', 'Koibatek', 'Kisii', 'Nyamira', 'Bungoma/Mt Elgon',
#        'Homa Bay/Ndhiwa Suba', 'Narok North/South', 'Narok',
#        'Kisumu East/Kisumu West', 'Meru South', 'Murang’a', 'Kilifi',
#        'Muranga', 'Nandi', 'Meru North', 'Kisumu East/West',
#        'Kajiado North', 'Homa–Bay', 'Kisii Central', 'Mwingi', 'Kericho',
#        'Ugenya/Ugunja', 'Malindi', 'Homa-Bay', 'Busia/ Teso',
#        'Bomet/Buret/Sotik', 'Bomet/Bureti/Sotik', 'Baringo', 'Homabay',
#        'Isiolo', 'Kericho/Bureti/Kipkelion', 'Taita/Taveta', 'Bomet',
#        'Muhoroni', 'Homa Bay', 'Trans Nzoia/West Pokot',
#        'KisumuEast/ West', 'Transmara', 'TransMara', 'Trans Mara',
#        'Koibatek/Mogotio', 'KerichoBureti', 'Ugenya',
#        'Kisumu Town East/West', 'Taita Taveta', 'Isiolo/Marsabit',
#        'Trans Nzoia/West pokot', 'Bungoma/MtElgon', 'Bungoma/Mt Kenya',
#        'Meru North Dictrict', 'Kisii Central Dictrict',
#        'Meru Central Dictrict', 'Meru Central', 'Kericho/Bureti/Sotik',
#        'Kisumu East/ West', 'Kwale County', 'Laikipia Distri',
#        'is revoked', 'Vihiga/Emuhaya', 'Kilifi/Malindi/Kaloleni',
#        'Kilifi/Malindi/Kaloleni/Ganze', 'Garissa', 'Kiambu Distri',
#        'Nairob', 'Nyeri Dist', 'Ukwala', 'Nyandarua',
#        'Kilifi/Kaloleni/Malindi', 'Bondo/Rarieda', 'Laikiapa',
#        'Rachuonyo South/North', 'Emuhaya', 'Hamisi', 'Migori', 'Sabatia',
#        'Rachuonyo North/South', 'Kwale/Msambweni/Kinango', 'NAIROBI',
#        'Lamu/Tana River', 'Kwale Distri', 'Nyando/Nyakach/Muhoroni',
#        'Nyandrua/Samburu', 'Meru North Distric', 'Kisii Centaral',
#        'Vihiga/Emuhaya/ Sabatia/Hamisi', 'Bomet/Bureti/ Sotik',
#        'Vihiga/Sabatia/Hamisi/Emuhaya', 'Nyando/Muhoroni/Nyakach',
#        'West Pokot', 'National Land Commission', 'Life',
#        'Ordinary Life Operations', 'Vihiga/Sabatia/Hamisi',
#        'West Pokot1204', 'Nyahururu/Samburu', 'Nyakach', 'Thika/Gatundu',
#        'Gatundu', 'Kisumu East//West', 'Elgeyo/Marakwet', 'and whereas',
#        'Rachuonyo East/South/North', 'Meru South/Maara/Tharaka',
#        'Rachuonyo East', 'Kapenguria', 'Murang a', 'Ugunja/Ugenya',
#        'Narok North/ South', 'Rachuonyo North/East/South',
#        'Gatundu/Thika', 'Koibatek/Mugotio', 'Bondo/Rarienda',
#        'Bungoma/ Mt Elgon', 'Trans Nzoia County', 'Usin Gishu',
#        'Machakos Distric', 'Elgeyo Marakwet', 'Luanda', 'Buisa/Teso',
#        'Nyandarua/Sambura', 'Kisumu/East/West', "Murang'a",
#        'Tharaka Nithi', 'Bumgoma/Mt Elgon', 'Vihiga/Emuhaya/Hamisi',
#        'Busia/Teso (K)', 'Nyeri Dis', 'Mbeere North/South',
#        'Meru South/ Tharaka', 'Ruiru', 'Meru South/Tharaka', 'Kajido',
#        '2019', 'Nyandarua Distric', 'Meru Distri',
#        'Narok North/South Districsts', 'Laikipia County'], dtype=object)

# %%
df_districts.District.unique()
# Out:
# array(['Baringo', 'Bomet', 'Bondo', 'Bungoma', 'Buret', 'Busia',
#        'Butere/Mumias', 'Embu', 'Garissa', 'Gucha', 'Homa Bay', 'Ijara',
#        'Isiolo', 'Kajiado', 'Kakamega', 'Keiyo', 'Kericho', 'Kiambu',
#        'Kilifi', 'Kirinyaga', 'Kisii Central', 'Kisumu', 'Kitui',
#        'Koibatek', 'Kuria', 'Kwale', 'Laikipia', 'Lamu', 'Lugari',
#        'Machakos', 'Makueni', 'Malindi', 'Mandera', 'Maragua', 'Marakwet',
#        'Marsabit', 'Mbeere', 'Meru Central', 'Meru North', 'Meru South',
#        'Migori', 'Mombasa', 'Mount Elgon', 'Moyale', "Murang'a", 'Mwingi',
#        'Nairobi', 'Nakuru', 'Nandi', 'Narok', 'Nyamira', 'Nyandarua',
#        'Nyando', 'Nyeri', 'Rachuonyo', 'Samburu', 'Siaya', 'Suba',
#        'Taita Taveta', 'Tana River', 'Teso', 'Tharaka', 'Thika',
#        'Trans Mara', 'Trans Nzoia', 'Turkana', 'Uasin Gishu', 'Vihiga',
#        'Wajir', 'West Pokot'], dtype=object)

# %% [markdown]
# ### Merge the main dataframe to include the districts' information

# %%
df_large_districts = pd.merge(df_large, df_districts, left_on='notice_loc', right_on='District', how='left')
df_large_districts.head()
# Out:
#                                                                         key_0  \
# 0  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 1  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 2  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 3  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 4  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
#
#    index  year                                             url_year  \
# 0      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 1      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 2      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 3      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
# 4      0  2010  http://kenyalaw.org/kenya_gazette/gazette/year/2010
#
#                                                                 gazette_links  \
# 0  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 1  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 2  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 3  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 4  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
#
#             volume_num                             volume_date  \
# 0  Vol. CXII - No. 135  NAIROBI, \n\t\t    \t31 December,2010
# 1  Vol. CXII - No. 135  NAIROBI, \n\t\t    \t31 December,2010
# 2  Vol. CXII - No. 135  NAIROBI, \n\t\t    \t31 December,2010
# 3  Vol. CXII - No. 135  NAIROBI, \n\t\t    \t31 December,2010
# 4  Vol. CXII - No. 135  NAIROBI, \n\t\t    \t31 December,2010
#
#                                                                    volume_url  \
# 0  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 1  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 2  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 3  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
# 4  http://kenyalaw.org/kenya_gazette/gazette/volume/Mjg0/Vol. CXII - No. 135/
#
#            notice_num_title         notice_act_title         notice_num_year  \
# 0  Gazette Notice No. 16759  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 1  Gazette Notice No. 16760  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 2  Gazette Notice No. 16761  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 3  Gazette Notice No. 16762  THE REGISTERED LAND ACT  (Cap. 300, section 35)
# 4  Gazette Notice No. 16763  THE REGISTERED LAND ACT  (Cap. 300, section 35)
#
#                       notice_sub_title  \
# 0  Issue of a New Certificate of Lease
# 1       Issue of a New Land Title Deed
# 2       Issue of a New Land Title Deed
# 3       Issue of a New Land Title Deed
# 4       Issue of a New Land Title Deed
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         notice_body  \
# 0                       WHEREAS Francis Meso, of P.O. Box 52540, Nairobi in the Republic of Kenya, is registered as proprietor in leasehold interests of that piece of land containing 0.0141 hectare or thereabouts, situate in the city of Nairobi, registered under title No. Nairobi Block 93/686, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new certificate of lease provided that no objection has been received within that period.
# 1                WHEREAS Milcah Wangui Wambura, of P.O. Box 42660, Nairobi in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 7.6 acres or thereabout, situate in the city of Nairobi, registered under title No. Dagoretti/Mutuini/309, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 2                                                   WHEREAS Joseph Muchiri Kenja, is registered as proprietor in absolute ownership interest of that piece of land containing 0.045 hectare or thereabouts, situate in the district of Nakuru, registered under title No. Nakuru/Municipality Block 22/607, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 3          WHEREAS Charles Kangangi, of P.O. Box 11, Subukia in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 1.445 hectares or thereabout, situate in the district of Nakuru, registered under title No. Subukia/Subukia Block 3/113, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 4  WHEREAS John Njenga Kariuki, of P.O. Box 14938, Nakuru in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 0.047 hectare or thereabouts, situate in the district of Nakuru, registered under title No. Kiambogo/Kiambogo Block 2/6772, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
#
#                       notice_date notice_registrar_name  \
# 0  Dated the 31st December, 2010.        B. K. LEITICH,
# 1  Dated the 31st December, 2010.        B. K. LEITICH,
# 2  Dated the 31st December, 2010.         J. M. MWAURA,
# 3  Dated the 31st December, 2010.         J. M. MWAURA,
# 4  Dated the 31st December, 2010.             M. SUNGU,
#
#              notice_num_loc notice_loc District      HASC    Cod  Population  \
# 0  Land Registrar, Nairobi.    Nairobi  Nairobi  KE.NA.NB  101.0   2143254.0
# 1  Land Registrar, Nairobi.    Nairobi  Nairobi  KE.NA.NB  101.0   2143254.0
# 2           Land Registrar,         Na      NaN       NaN    NaN         NaN
# 3           Land Registrar,         Na      NaN       NaN    NaN         NaN
# 4           Land Registrar,         Na      NaN       NaN    NaN         NaN
#
#    Area(km.²)  Capital    district_named
# 0       696.0  Nairobi  Nairobi District
# 1       696.0  Nairobi  Nairobi District
# 2         NaN      NaN               NaN
# 3         NaN      NaN               NaN
# 4         NaN      NaN               NaN

# %%
df_large_districts.to_csv('titles_new_df_large_districts.csv')

# %% [markdown]
# # In this next section, I use regex and other relevant scraping techniques to extract more information from the notices.
#
# ## This is what one land-related gazette notice looks like:
#
# ![Landing Page for 2022](one_land_related_gazette_notice.png)
#
# ### Here are some of the columns created:
#
# * First person named in a title: first_named
# * Area of land referenced: acres_hectares
# * Title deed number: title_number
# * ID number of first person named: first_ID
# * Address details of first person named: first_address
# * LR number: lr_num
# * Municipality referenced: municipality
# * Second person named in a title: second_person
# * IR number: ir_num
# * Number of days to expiration: days
# * Succession cause number: succession
# * township: township
# * district: in_the_district_of
# * province code: province_code

# %%
df_large_districts.notice_sub_title=df_large_districts.notice_sub_title.str.upper()
df_large_districts.notice_sub_title.unique()
# Out:
# array(['ISSUE OF A NEW CERTIFICATE OF LEASE',
#        'ISSUE OF A NEW LAND TITLE DEED', 'REGISTRATION OF INSTRUMENT',
#        'OPENING OF A NEW REGISTER', 'THE REGISTERED LAND ACT', nan,
#        'ISSUE OF A NE W LAND TITLE DEED', '(CAP. 280)',
#        'RECONSTRUCTION OF A WHITE AND GREEN CARD',
#        'ISSUE OF NEW LAND TITLE DEEDS', 'PROHIBITION (RESTRICTION) ORDER',
#        'ISSUE OF A NEW LAND TILE DEED', 'ISSUE OF A NEW LAND TILE DEEDS',
#        'ISSUE OF A NEW LAND TITTLE DEED',
#        'ISSUE OF A NEW LAND TTITLE DEED',
#        'ISSUE OF A NEW LAND CERTIFICATE', 'ISSUE OF NEW LAND TITLE DEED',
#        'RECONSTRUCTION OF GREEN CARD AND WHITE CARD',
#        'ISSUE OF A NEW CERTIFICATE OF TITLE',
#        'ISSUE OF A NEW CERTIFATE OF LEASE',
#        'RECONSTRUCTION OF WHITE AND GREEN CARD',
#        'RECONSTRUCTION OF GREEN CARD AND WHITE',
#        'WHEREAS (1) MOHAMED BIN SALIM, (2) RUKIYA BINT SALIM AND (3) FATUMA BINT ABDREHMAN, ALL OF P.O. BOX 74, LAMU IN THE REPUBLIC OF KENYA, IS REGISTERED PROPRIETOR IN ABSOLUTE OWNERSHIP INTEREST OF THAT PIECE OF LAND CONTAINING 0.025 HECTARE OR THEREABOUTS, SITUATE IN THE DISTRICT OF LAMU, REGISTERED UNDER TITLE NO. LAMU/BLOCK 1/868, AND WHEREAS SUFFICIENT EVIDENCE HAS BEEN ADDUCED TO SHOW THAT THE LAND TITLE DEED ISSUED THEREOF HAS BEEN LOST, NOTICE IS GIVEN THAT AFTER THE EXPIRATION OF SIXTY (60) DAYS FROM THE DATE HEREOF, I SHALL ISSUE A NEW LAND TITLE DEED PROVIDED THAT NO OBJECTION HAS BEEN RECEIVED WITHIN THAT PERIOD.',
#        'WHEREAS HANNAH NYAMBURA KARANJA (ID/13307271), OF P.O. BOX 52142, NAIROBI IN THE REPUBLIC OF KENYA, IS REGISTERED PROPRIETOR IN ABSOLUTE OWNERSHIP INTEREST OF THAT PIECE OF LAND CONTAINING 0.025 HECTARE OR THEREABOUTS, SITUATE IN THE DISTRICT OF KIAMBU, REGISTERED UNDER TITLE NO. KIAMBAA/KIHARA/3389, AND WHEREAS SUFFICIENT EVIDENCE HAS BEEN ADDUCED TO SHOW THAT THE LAND TITLE DEED ISSUED THEREOF HAS BEEN LOST, NOTICE IS GIVEN THAT AFTER THE EXPIRATION OF SIXTY (60) DAYS FROM THE DATE HEREOF, I SHALL ISSUE A NEW LAND TITLE DEED PROVIDED THAT NO OBJECTION HAS BEEN RECEIVED WITHIN THAT PERIOD.',
#        'ISSUE OF A GREEN AND WHITE CARD',
#        'ISSUE OF A NEW LAND TITLE DEEDS', 'OPENING OF NEW REGISTERS',
#        'REGISTRATION OF INSTRUMENTS', '(CAP.  280)',
#        'ISSUE A OF NEW LAND TITLE DEED', '(CAP.  288)',
#        'SSUE OF A NEW LAND TITLE DEED',
#        'ISSUE OF A NEW LEASE CERTIFICATE', 'THE GOVERNMENT LANDS ACT',
#        'RECONSTRUCTION OF GREEN AND WHITE CARDS',
#        'APPLICATION TO BRING LAND UNDER THE OPERATION OF THE ACT',
#        'DATED THE  16TH SEPTEMBER, 2011.', 'OPENING A NEW REGISTER',
#        'REGISTRATION OF AN INSTRUMENT', 'ISSUE OF NEW TITLE DEEDS',
#        'ISSUE OF A NEW LEASE TITLE DEED',
#        'OPENING OF A NEW REGISTER (GREEN CARD)',
#        'ISSUE OF  NEW LAND TITLE DEEDS',
#        'ISSUE OF A NEW LAND REGISTER (GREEN CARD)', 'LOSS OF GREEN CARD',
#        'ISSUE OF A NEW TITLE DEED', 'ISSUE OF A NEW TITLE OF DEED',
#        'OPENING OF  NEW REGISTERS', 'RECTIFICATION OF REGISTER',
#        'OPENING  OF A NEW REGISTER', 'ISSUE OF A PROVISIONAL CERTIFICATE',
#        'REMOVAL OF CAUTION', 'ISSUE OF A NEW LAND TITLE DEE',
#        'RECTIFICATION OF TITLE', 'OPENING F A NEW REGISTER',
#        'THE TRUST LAND ACT', 'ISSUE OF A NEWINWW LAND TITLE DEED',
#        'ISSUE OF A NEW GREEN AND WHITE CARD',
#        'ISSUE OF A CERTIFICATE OF LEASE',
#        'ISSUE OF A CERTIFICATE OF TITLE', 'RECONSTRUCTION OF GREEN CARD',
#        'ISSUE OF A DUPLICATE CERTIFICATE OF LEASE',
#        'LOSS OF LAND REGISTER', 'ISSUE OF A NEW LAND LEASE',
#        'CANCELLATION OF REVOCATION OF TITLE DEED',
#        'ISSUE OF CERTIFICATE OF LEASE',
#        'RECONSTRUCTION OF WHITE AND GREEN CARDS',
#        'CANCELLATION OF LAND TITLE DEED', 'LOSS OF GREEN CARDS',
#        '(CAP. 300, SECTION 35)',
#        'RECONSTRUCTION OF LOSTOR DESTROYED LAND REGISTER',
#        'ISSUE OF DUPLICATE CERTIFICATE OF LEASE',
#        'ISSUE OF  DUPLICATE CERTIFICATE OF LEASE',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGISTERS',
#        'RECTIFICATION OF A REGISTER', 'LOSS OF WHITE CARD',
#        'LOSS OF A GREEN CARD', 'OPENING OF A NEW REGISTERS',
#        'ISSUE OF DUPLICATE NEW CERTIFICATE OF LEASE',
#        'ISSUE OF OF A NEW LAND TITLE DEED',
#        'ISSUE OF NEW LAND CERTIFICATE OF LEASE',
#        'OPPENING OF A NEW REGISTER', 'ISSUE OF NEW A LAND TITLE DEED',
#        'ISSUE OF A NEW LAND TITLE DEED ',
#        'RECONSTRUCTION OF LOST OR DESTOYED LAND',
#        'RECONSTRUCTION OF THE REGISTER',
#        'ISSUE OF NEW CERTIFICATE OF LEASE',
#        'OPENING OF A NEW REGISTER/GREEN CARD', 'ISSUE OF NEW GREEN CARDS',
#        'LOSS OF A LAND REGISTER', '(NO. 3 OF 2012)',
#        'LOSS OF LAND REGISTERS', 'RECTIFICATION BY ORDER OF COURT',
#        'ISSUE OF A NEW LAND REGISTER',
#        'ISSUE OF A NEW CERTIFFICATE OF LEASE',
#        'ISSUE OF A NEW WHITE CARD', 'OPENING OF NEW LAND REGISTERS',
#        'ISSUE OF A PROVISIONAL CERTIFICATE OF LEASE',
#        'ISSUE OF NEW GREEN CARD', 'ISSUE OF A GREEN CARD',
#        'ISSUE OF A NEW DUPLICATE CERTIFICATE OF LEASE',
#        'ISSUE OF PROVISIONAL CERTIFICATE',
#        'ISSU OF A NEW LAND TITLE DEED', 'OPENING OF A NEW GREEN CARD',
#        'ISSUE OF PROVISIONAL CERIFICATE', 'ISSUE OF A PROVISIONAL ',
#        'ISSUE OF PROVISIONAL CERTFICATE',
#        'RECOSTRUCTION OF LOST OR DESTROYED LAND REGISTER',
#        'ISSUE OF NEW LAND TITLE DEEDISSUE OF NEW LAND TITLE DEEDS',
#        'ISSUE OF A CERTIFIED COPY OF TITLE',
#        'DECLARATION OF OPENING A NEW GREEN CARD',
#        'RECONSTRUCTION OF FILE', 'ISSUE OF PROVISIONAL CERTIFICATE.',
#        'CANCELLATION OF INVALID CERTIFICATE  OF LEASE',
#        'ISSUE OF A NEW GREENCARD', 'OPENING OF A NEW REGISTER.',
#        'REGISTRATION OF TRANSFER', 'ISSUE OF A NEW CERTIFICATE OF LEASE.',
#        'ISSUE OF NEW LAND TITLE DEEDS.',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGISTER.',
#        'RECONSTRUCTION OF LOST OR DESSTROYED LAND REGISTER.',
#        'RECONSTRUCTION OF LOST DESTROYED LAND REGISTER.',
#        'REGISTRATION OF INSTRUMENT.',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGISTER AND WHITE CARD',
#        'ISSUANCE OF PROVISIONAL INDENTURE',
#        'FORMS FOR LEASES AND GRANTS TO PUBLIC LAND',
#        'OPENING OF NEW REGISTER', 'LOSS OF POLICY',
#        'HEAD OFFICE: P.O. BOX 30375–00100, NAIROBI',
#        'HEAD OFFICE: P.O. BOX 34172, NAIROBI', 'LOSS OF POLICIES',
#        'LOSS OF TITLE DEED', 'LOSS OF GREEN/WHITE CARD',
#        'ISSUE OF A PROVISIONAL INDENTURE',
#        'ISSUE OF PROVISIONAL CERTIFICATES',
#        'RECONSTRUCTION OF A DEED FILE',
#        'REGISTRATION OF INSTRUMENTREGISTRATION OF INSTRUMENT',
#        'REGISTRATION OF INSTRUMENTREGISTRATION OF INSTRUMENTS',
#        'RECONSTRUCTION OF LAND REGISTER', 'CAUTION REMOVAL',
#        'ISSUE OF A PROVISION AL CERTIFICATE',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGTISTER',
#        'ISSUE OF A PROVOSIONAL CERTIFICATE OF TITLE',
#        'ISSUE OF A PROVISIONAL CERTIFICATE OF TITLE',
#        'OPENING OF REGISTER', 'ISSUE OF A PROVISIONAL CERTIFICATE ',
#        'ISSUE OF A NEW CERTIFICATE OF LEASE ',
#        'ISSUE  OF A NEW LAND TITLE DEED ',
#        'ISSUE OF A NEW LAND TITLE DEEED',
#        'ISSUE OF A NEW CERTIFCATE OF LEASE', 'ISSUE OF A NEW LAND TITLE',
#        'ISSUE  OF A PROVISIONAL CERTIFICATE ',
#        'ISSUE OF A NEW LAND TITLE DEEDS ',
#        'ISSUE OF A NEW LAND TITTLE DEED ', 'ISSUE OF A NEW TITLE DEED ',
#        'ISSUE OF  AN NEW LAND TITLE DEED',
#        'ISSUR OF A NEW LAND TITLE DEEDS',
#        'ISSUE OF NEW LAND TITLE DEEDS ',
#        'ISSUE OF  A NEW LAND TITLE DEED',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGISTER ',
#        'ISSUE OF A NEW GREEN CARD ', 'REGISTRATION OF INSTRUMENT ',
#        'REGISRATION OF INSTRUMENT ', 'REGISRATION OF INSTRUMENT',
#        'ISSUE OF A PROVISION CERTIFICATE ',
#        'ISSUE OF A PROVISIONAL SUB-LEASE',
#        'RECONSTRUCTION OF A NEW GREEN CARD',
#        'CANCELLATION OF CERTIFICATE OF TITLE',
#        'RECONSTRUCTION OF NEW GREEN CARD',
#        'REGISTRATION OF ORDER OF COURT', 'ISSUE OF NEW TITLE DEED',
#        'RECONSTRUCTION OF A WHITE CARD', 'RECONSTRUCTION OF A GREEN CARD',
#        'OPENING A NEW LAND REGISTER', 'ISSUE OF A PROVISIONAL CERTIFACTE',
#        'RECONSTRUCTION OF WHITE CARD', 'ISSSUE OF NEW TITLE DEEDS',
#        'RECONSTRUCTION OF A LAND REGISTER',
#        'ISSUE OF A NEW CERTIFICATES OF LEASE',
#        'RECTIFICATION BY LAND REGISTRAR',
#        'RECONSTRUCTION OF A LOST OR MISPLACED GREEN CARD',
#        'MR/3556886                                                     DIRECTOR-GENERAL.',
#        'ISSUE OF A NEW LAND TITLE ',
#        'ISSUE OF TITLE DEED AND REGISTRATION OF INSTRUMENT',
#        'ISSUE OF A  NEW LAND TITLE DEED', 'OPEENING OF A NEW REGISTER',
#        'REGISTRATION OF INTSTRUMENT',
#        'RECONSSTRUCTION OF LOST OR DESTROYED LAND REGISTER',
#        'OPENING OF NEW LAND REGISTER', 'ISSUE OF NEW LAND TITLE DEEEDS',
#        'ISSUE OF A NEW LAND TITLTE DEED', 'ISSUE OF A NEEW TITLE DEED',
#        'REGISTRTION OF INSTRUMENT', 'RECONSTRUCTION OF GREEN CARDS',
#        'RECONSTRUCTION OF NEW GREEN AND WHITE CARDS',
#        'RECONSTRUCTION OF LOST OR DESTRYOED LAND REGISTER',
#        'ISSUE OF A NEW GREEN AND WHITE CARDS', 'REGISTRATION ',
#        'LOSS OF REGISTER', 'REGISTRATIONS OF INSTRUMENTS',
#        'ISSUE OF A ROVISIONAL CERTIFICATE',
#        'ISSUE OF A PROVISINAL INDENTURE',
#        'RECONSTRUCTION OF LOST GREEN CARD',
#        'ISSUE OF A PROVISIONAL CERTIFICATE OF TITLE ',
#        'ISSUE OF A PROVISIONAL LAND TITLE DEED',
#        'ISSUE OF CERTIFICATE OF LEASES',
#        'ISSUE OF NEW LAND TITLE DEEDS           ',
#        'ISSUE OF A PROVISIONAL CERTIFICATE OF LEASE ',
#        'ISSUE OF A NEW  LAND TITLE DEED ',
#        'ISSUE OF A PROVISINAL CERTIFICATE',
#        'RECONSTRUCION OF LOST OR DESTROYED LAND REGISTER',
#        'RECONSTRUCTION OF LOST OR DESTROYED LAND REGSITER',
#        'RECONSTRUCTION OF LOST OR DESYTROYED LAND REGISTER',
#        'RECONSTRUCTION OF LOST OR DESTROYED AND REGISTER',
#        'ISSUE OF A NEW LAND TITLE DEED  ',
#        'RECONSTRUCTION OF LOST GREEN CARDS', 'REGISTARTION OF INSTRUMENT',
#        'OPENING OF A REGISTER', 'ISSUE OF A PROVISIONAL CERTIFCATE',
#        'DEGAZETTEMENT ', 'ISSUE OF A NEW  LAND TITLE DEED',
#        'ISSUE OF A PROVIVIONAL CERTIFICATE',
#        'LOSS OF GREEN AND WHITE CARDS',
#        'CANCELLATION OF ENTRIES IN THE LAND REGISTER AND ISSUANCE OF PROVISIONAL TITLE',
#        'ISSUE OF A NEW GREEN/WHITE CARD',
#        'REINSTATEMENT OF TITLE NUMBER KWALE/DIANI SS/81',
#        '                                                             OPENING OF LAND REGISTERS',
#        ' ISSUE OF A PROVISIONAL CERTIFICATE',
#        'RECONSTRUCTION OF  LOST OR DESTROYED LAND REGISTER', 'REVOCATION',
#        'ISSUE OF A NEW LAND ',
#        'RECONTSRUCTION OF LOST OR DESTROYED LAND REGISTER',
#        'REGISTRATION OF INTSRUMENT', 'REGISTRATION OF INSRUMENT',
#        'ISSUE OF A WHITE CARD', 'LOSS OF  GREEN CARD',
#        'RECONSTRUCTION OF LOST OR DESTROYED  OF LAND REGISTER',
#        '                            RECONSTRUCTION OF LOST OR DESTROYED LAND REGISTER',
#        '                                                                                            ISSUE OF A NEW LAND TITLE DEED',
#        '                                                                                             ISSUE OF NEW LAND TITLE DEEDS',
#        '                                                                                       ISSUE OF NEW LAND TITLE DEED',
#        '                                                                                                OPENING OF A NEW LAND REGISTER',
#        '  REGISTRATION OF INSTRUMENT',
#        'CANCELLATION OF A LAND TITLE DEED',
#        'THE LAND REGISTRATION (GENERAL) REGULATIONS, 2017'], dtype=object)

# %%
df_large_districts['first_named']=df_large_districts.notice_body.str.extract("WHEREAS ([A-Z][\w ]*)[^ \w]")

# %%
df_large_districts.sample(5)
# Out:
#                                                                               key_0  \
# 228064  http://kenyalaw.org/kenya_gazette/gazette/volume/MjE5Nw--/Vol.CXXII-No.150/
# 134884   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2NA--/Vol.CXVII-No.47/
# 176410   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEyMQ--/Vol.CXVII-No.20/
# 126105   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2OQ--/Vol.CXVII-No.52/
# 51719   http://kenyalaw.org/kenya_gazette/gazette/volume/MTIzMA--/Vol.CXVII-No.114/
#
#         index  year                                             url_year  \
# 228064     10  2020  http://kenyalaw.org/kenya_gazette/gazette/year/2020
# 134884      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 176410      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 126105      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 51719       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
#
#                                                                       gazette_links  \
# 228064  http://kenyalaw.org/kenya_gazette/gazette/volume/MjE5Nw--/Vol.CXXII-No.150/
# 134884   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2NA--/Vol.CXVII-No.47/
# 176410   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEyMQ--/Vol.CXVII-No.20/
# 126105   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2OQ--/Vol.CXVII-No.52/
# 51719   http://kenyalaw.org/kenya_gazette/gazette/volume/MTIzMA--/Vol.CXVII-No.114/
#
#               volume_num                             volume_date  \
# 228064  Vol.CXXII-No.150    NAIROBI, \n\t\t    \t07 August,2020
# 134884   Vol.CXVII-No.47       NAIROBI, \n\t\t    \t08 May,2015
# 176410   Vol.CXVII-No.20  NAIROBI, \n\t\t    \t27 February,2015
# 126105   Vol.CXVII-No.52       NAIROBI, \n\t\t    \t22 May,2015
# 51719   Vol.CXVII-No.114   NAIROBI, \n\t\t    \t23 October,2015
#
#                                                                          volume_url  \
# 228064  http://kenyalaw.org/kenya_gazette/gazette/volume/MjE5Nw--/Vol.CXXII-No.150/
# 134884   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2NA--/Vol.CXVII-No.47/
# 176410   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEyMQ--/Vol.CXVII-No.20/
# 126105   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE
lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue new title deeds provided that no objection has been received within that period.
#
#                            notice_date notice_registrar_name  \
# 228064     Dated the 7th August, 2020.       H. N. KHAREMWA,
# 134884        Dated the 8th May, 2015.         P. A. NYANJA,
# 176410  Dated the 27th February, 2015.         W. N. MUGURO,
# 126105       Dated the 22nd May, 2015.          C. W. NJAGI,
# 51719    Dated the 23rd October, 2015.        C. W. MWANIKI,
#
#                                                                                                                                        notice_num_loc  \
# 228064  MR/0783823                                                                                                    Land Registrar, Nakuru District
# 134884                                                                            MR/7407161                 Land Registrar, Ugenya/Ugunja Districts.
# 176410                                                                      MR/6901371                               Land Registrar, Kiambu District.
# 126105                                                                       MR/7413661                           Land Registrar, Kirinyaga District.
# 51719                                                                        MR/8220865                            Land Registrar, Naivasha District.
#
#            notice_loc   District      HASC    Cod  Population  Area(km.²)  \
# 228064         Nakuru     Nakuru  KE.RV.NK  709.0   1187039.0      7242.0
# 134884  Ugenya/Ugunja        NaN       NaN    NaN         NaN         NaN
# 176410             Na        NaN       NaN    NaN         NaN         NaN
# 126105      Kirinyaga  Kirinyaga  KE.CE.KY  202.0    457105.0      1478.0
# 51719        Naivasha        NaN       NaN    NaN         NaN         NaN
#
#                Capital      district_named             first_named
# 228064          Nakuru     Nakuru District   Esther Nyambura Kambo
# 134884             NaN                 NaN  Francis Onyango Jagam
# 176410             NaN                 NaN   Moses Mbogwah Mainah
# 126105  Kerugoya/Kutus  Kirinyaga District    Samuel Mwangi Nyaga
# 51719              NaN                 NaN       Mary Njoki Nguru

# %%
df_large_districts.notice_body.sample(10)
# Out:
# 35109                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 WHEREAS Joseph Wandera Odanga, is registered as proprietor in absolute ownership interest of that piece of land containing 0.39 hectare or thereabouts, situate in the district of Busia/Teso, registered under title No. Samia/Luanda/Mudoma/557, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 192539                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             WHEREAS Christine Mambori M., of P.O. Box 26, Werugha in the Republic of Kenya, is registered as proprietor of that piece of land known as Kwale/Shimoni/491, situate in the district of Kwale, and whereas sufficient evidence has been adduced to show that the green card issued in respect thereof is lost and efforts to trace it in the office have failed, notice is given that after the expiration of sixty (60) days from the date hereof, provided that no valid objection has been received within that period, I shall open a new register.
# 217850                                                                                                                                                                                                                                                                                                                                                                                                                                                     WHEREAS (1) Henry Mugo Ngari (ID/10161535), (2) Anthony Wachira Muita (ID/6063978) and (3) John Waweru Kiama (ID/10160759), all of P.O. Box 3, Kagio in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 0.4 hectare or thereabouts, situate in the district of Kirinyaga, registered under title No. Mwerua/Kabiriri/1825, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 197326                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  WHEREAS Tamu Holdings Limited, of P.O. Box 44776, Nairobi in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 3.0 hectares or thereabout, situate in the district of Muhoroni, registered under title No. Kisumu/God Abuoro/4, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 81973                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     WHEREAS Fairways Royale Company Limited, of P.O. Box 1588, Nairobi in the Republic of Kenya, is registered proprietor of all that piece of land known as L.R. No. 209/19302, situate in the district of Kiambu, by virtue of a lease registered as I.R. 124140, and whereas the land register in respect thereof is lost or destroyed, and whereas efforts made to locate the said land register have failed, notice is given that after the expiration of sixty (60) days from the date hereof, the property register shall be reconstructed under the provisions of section 33 (5) of the Act, provided that no objection has been received within that period.
# 141360    WHEREAS Ithinji Kithuguru (deceased), is registered as proprietor of that piece of land known as Abothuguchi/Kariene/188, situate in the district of Meru, and whereas the High Court in succession cause No. 486 of 2011, has issued grant of letters of administration and certificate of confirmation of grant in favour of Joseph Muthuri Nchani, and whereas the said court has executed an application to be registered as proprietor by transmission of R. L. 19, and whereas the land title deed issued earlier to the said Ithinji Kithuguru (deceased) has been reported missing or lost, notice is given that after the expiration of thirty (30) days from the date hereof, provided no valid objection has been received within that period, I intend to dispense with the production of the said land title deed and proceed with registration of the said application to be registered as proprietor by transmission of R.L. 19 in the name of to Joseph Muthuri Nchani, and upon such registration the land title deed issued earlier to the said Ithinji Kithuguru (deceased), shall be deemed to be cancelled and of no effect.
# 229456                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         WHEREAS Peter Njuguna Mugekenyi (ID/3337242), is registered as proprietor in absolute ownership interest of all that piece of land situate in the district of Murang’a, registered under title No. Loc. 1.Kigio/T.2, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new land title deed provided that no objection has been received within that period.
# 116516                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               WHEREAS David Ndungu Njoroge (ID/3433810), of P.O. Box 471–00208, Ngong Hills in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 0.203 hectare or thereabouts, situate in the district of Kajiado, registered under title No. Ngong/Ngong/24560, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 129395                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     WHEREAS Kathenge Kilile, of P.O. Box 350–90200, Kitui in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 2.8 hectares or thereabout, situate in the district of Kitui, registered under title No. Kyangwithya/Ndumoni/367, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 193741                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         WHEREAS Frieda Obonyo Maranga (ID/2760413), of P.O. Box 29–40200, Kisii in Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 2.160 hectares or thereabout, situate in the district of Nyamira, registered under title No. Central Kitutu/Mwabosire/1744, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# Name: notice_body, dtype: object

# %%
df_large_districts['acres_hectares']=df_large_districts.notice_body.str.extract("containing ([\d.]+ hectares)")
# df_large_districts['acres_hectares']=df_large_districts.notice_body.str.extract("containing ([\d]+[.]*[\d]+) acres")+" acres"

df_large_districts['acres_hectares'].sample(10)
# Out:
# 207945     3.0 hectares
# 107845     3.2 hectares
# 166727              NaN
# 14602               NaN
# 75484     2.00 hectares
# 65178               NaN
# 207749              NaN
# 5221                NaN
# 22972               NaN
# 168435    1.01 hectares
# Name: acres_hectares, dtype: object

# %%
df_large_districts['acres_hectares']=df_large_districts['acres_hectares'].fillna(df_large_districts.notice_body.str.extract("containing ([\d.]+ acres)", expand=False))
df_large_districts['acres_hectares'].sample(10)
# Out:
# 123181             NaN
# 145113             NaN
# 41210              NaN
# 16149              NaN
# 113624             NaN
# 177090         6 acres
# 65421              NaN
# 163772    4.0 hectares
# 134155             NaN
# 134779             NaN
# Name: acres_hectares, dtype: object

# %%
df_large_districts['title_number']=df_large_districts.notice_body.str.extract("title No. ([^,]+),") 
# df_large_districts['first_named']=df_large_districts.notice_body.str.extract("WHEREAS ([A-Z][\w ]*)[^ \w]")
df_large_districts['title_number'].sample(10)
# Out:
# 169707                         Nya/Kitiri/4954
# 377                      Bungoma/Kamakoiwa/130
# 187175                     Isukha/Shirere/2936
# 219210                                     NaN
# 141928                                     NaN
# 21263                     Kisumu/Kochieng/2382
# 163107                       Ngong/Ngong/20637
# 199987                Marama/Shinamwenyuli/317
# 50475     Pioneer/Ngeria Block 1 (EATEC)/12478
# 201035                       Nyaki/Thuura/1880
# Name: title_number, dtype: object

# %%
df_large_districts['first_ID']=df_large_districts.notice_body.str.extract("ID[/]([\d]+)\b") 
df_large_districts['first_ID'].sample(10)
# Out:
# 55316     NaN
# 58863     NaN
# 118089    NaN
# 86107     NaN
# 117966    NaN
# 87001     NaN
# 201948    NaN
# 2850      NaN
# 29184     NaN
# 224293    NaN
# Name: first_ID, dtype: object

# %%
df_large_districts.sample(10)
# Out:
#                                                                               key_0  \
# 185917   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 209845   http://kenyalaw.org/kenya_gazette/gazette/volume/MTMzMw--/Vol.CXVII-No.72/
# 80019    http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Nw--/Vol.CXVII-No.84/
# 154914   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE1MQ--/Vol.CXVII-No.34/
# 104021   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE4Mw--/Vol.CXVII-No.70/
# 119429   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE3Ng--/Vol.CXVII-No.58/
# 55107   http://kenyalaw.org/kenya_gazette/gazette/volume/MTIwOQ--/Vol.CXVII-No.101/
# 87105    http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5NA--/Vol.CXVII-No.83/
# 174909   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEyMQ--/Vol.CXVII-No.20/
# 150362   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE1Mw--/Vol.CXVII-No.37/
#
#         index  year                                             url_year  \
# 185917      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 209845      6  2016  http://kenyalaw.org/kenya_gazette/gazette/year/2016
# 80019       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 154914      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 104021      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 119429      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 55107       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 87105       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 174909      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 150362      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
#
#                                                                       gazette_links  \
# 185917   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 209845   http://kenyalaw.org/kenya_gazette/gazette/volume/MTMzMw--/Vol.CXVII-No.72/
# 80019    http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Nw--/Vol.CXVII-No.84/
# 154914   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE1MQ--/Vol.CXVII-No.34/
# 104021   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE4Mw--/Vol.CXVII-No.70/
# 119429   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE3Ng--/Vol.CXVII-No.58/
# 55107   http://kenyalaw.org/kenya_gazette/gazette/volume/MTIwOQ--/Vol.CXVII-No.101/
# 87105    http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5NA--/Vol.CXVII-No.83/
# 174909   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEyMQ--/Vol.CXVII-No.20/
# 150362   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE1Mw--/Vol.CXVII-No.37/
#
#               volume_num                              volume_date  \
# 185917   Vol.CXVII-No.12   NAIROBI, \n\t\t    \t06 February,2015
# 209845   Vol.CXVII-No.72       NAIROBI, \n\t\t    \t01 July,2016
# 80019    Vol.CXVII-No.84     NAIROBI, \n\t\t    \t14 August,2015
# 154914   Vol.CXVII-No.34      NAIROBI, \n\t\t    \t02 April,2015
# 104021   Vol.CXVII-No.70       NAIROBI, \n\t\t    \t03 July,2015
# 119429   Vol.CXVII-No.58       NAIROBI, \n\t\t    \t05 June,2015
# 55107   Vol.CXVII-No.101  NAIROBI, \n\t\t    \t18 September,2015
# 87105    Vol.CXVII-No.83     NAIROBI, \n\t\t    \t07 August,2015
# 174909   Vol.CXVII-No.20   NAIROBI, \n\t\t    \t27 February,2015
# 150362   Vol.CXVII-No.37      NAIROBI, \n\t\t    \t10 April,2015
#
#                                                                          volume_url  \
# 185917   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 209845   http://kenyalaw.org/kenya_gazette/gazette/volume/MTMzMw--/Vol.CXVII-No.72/
# 80019    http://kenyalaw.org/kenya_gazette/gazette/volume/MTE
# 119429      MR/7413968                               Land Registrar, Kiambu District.
# 55107                     MR/8045905                  Land Registrar, Nyeri District.
# 87105   MR/7769896                                           Land Registrar, Nairobi.
# 174909  MR/6901351                                   Land Registrar, Kilifi District.
# 150362     MR/7054346                                  Land Registrar, Embu District.
#
#          notice_loc     District      HASC    Cod  Population  Area(km.²)  \
# 185917         Meru          NaN       NaN    NaN         NaN         NaN
# 209845        Siaya        Siaya  KE.NY.SI  609.0    480184.0      1520.0
# 80019         Thika        Thika  KE.CE.TH  206.0    645713.0      1960.0
# 154914  Uasin Gishu  Uasin Gishu  KE.RV.UG  716.0    622705.0      3328.0
# 104021      Kajiado      Kajiado  KE.RV.KJ  704.0    406054.0     21903.0
# 119429       Kiambu       Kiambu  KE.CE.KB  201.0    744010.0      1324.0
# 55107         Nyeri        Nyeri  KE.CE.NY  205.0    661156.0      3356.0
# 87105       Nairobi      Nairobi  KE.NA.NB  101.0   2143254.0       696.0
# 174909           Na          NaN       NaN    NaN         NaN         NaN
# 150362         Embu         Embu  KE.EA.EB  401.0    278196.0       729.0
#
#         Capital        district_named                  first_named  \
# 185917      NaN                   NaN              Robert Murithi
# 209845    Siaya        Siaya District           Francis Jow Adwodi
# 80019     Thika        Thika District   Rosemary Nyambura Mukundi
# 154914  Eldoret  Uasin Gishu District                 Kamau Ndatho
# 104021  Kajiado      Kajiado District      Simion Singeet Mutunkei
# 119429   Kiambu       Kiambu District          Samuel Kamau Muhia
# 55107     Nyeri        Nyeri District       Magdalene Njeri Kabura
# 87105   Nairobi      Nairobi District  Primrose Management Limited
# 174909      NaN                   NaN            Jacob Kitsao Yaa
# 150362     Embu         Embu District            Cyrus Maina Kamau
#
#         acres_hectares                       title_number first_ID
# 185917             NaN                                NaN      NaN
# 209845   2.15 hectares               North Gem/Siriwo/883      NaN
# 80019              NaN    Thika/Municipality Block 19/790      NaN
# 154914  1.694 hectares  Ngeria/Megun Block 3 (Kimuri)/158      NaN
# 104021             NaN       Kajiado/Kaputiei-North/30158      NaN
# 119429   2.34 hectares                Nguirubi/Ndiuni/815      NaN
# 55107              NaN               Othaya/Kihugiru/1444      NaN
# 87105              NaN                                NaN      NaN
# 174909    3.0 hectares               Kilifi/Ngerenyi/1156      NaN
# 150362             NaN                   Gaturi/Weru/4795      NaN

# %%
df_large_districts['first_ID']=df_large_districts.notice_body.str.extract("ID[/]([\d]+)") 
df_large_districts['first_ID'].sample(10)
# Out:
# 179763    16037840
# 223716         NaN
# 19880      8858117
# 153075         NaN
# 15621          NaN
# 55652      1844136
# 90454          NaN
# 136063     7670576
# 59539          NaN
# 223068         NaN
# Name: first_ID, dtype: object

# %%
df_large_districts['first_address']=df_large_districts.notice_body.str.extract("of (P.O. Box [\d-]+, [\w]+) in the Republic of") 
df_large_districts['first_address'].sample(10)

# of P.O. Box 3190–20100, Nakuru in the Republic of Kenya
# Out:
# 181337       P.O. Box 334, Kikuyu
# 45327                         NaN
# 157855                        NaN
# 159415      P.O. Box 84, Kakamega
# 186215       P.O. Box 26, Werugha
# 171919     P.O. Box 281, Naivasha
# 14822       P.O. Box 129, Kajiado
# 156982    P.O. Box 74628, Nairobi
# 208148     P.O. Box 3317, Nanyuki
# 149936                        NaN
# Name: first_address, dtype: object

# %%
df_large_districts['lr_num']=df_large_districts.notice_body.str.extract("all that piece of land known as L.R. No[s?]. ([\d]+/[\d]+),") 
df_large_districts['lr_num'].sample(12)



# all that piece of land known as L.R. No. 12570/174,
# Out:
# 153464    NaN
# 22938     NaN
# 225891    NaN
# 217923    NaN
# 200922    NaN
# 92485     NaN
# 165188    NaN
# 226641    NaN
# 173716    NaN
# 111021    NaN
# 10754     NaN
# 99463     NaN
# Name: lr_num, dtype: object

# %%
df_large_districts['municipality']=df_large_districts.notice_body.str.extract("in ([\w]+) Municipality") 
df_large_districts['municipality'].sample(10)
#in Nakuru Municipality
# Out:
# 58888     NaN
# 129471    NaN
# 25063     NaN
# 99511     NaN
# 213249    NaN
# 36314     NaN
# 230076    NaN
# 173095    NaN
# 19382     NaN
# 131154    NaN
# Name: municipality, dtype: object

# %%
df_large_districts['second_person']=df_large_districts.notice_body.str.extract("and [(]2[)] ([\w ]+),") 
df_large_districts['second_person'].sample(12)
#and (2) Shobna Bachulal Shah,
# Out:
# 58085                       NaN
# 159608                      NaN
# 139637                      NaN
# 72554                       NaN
# 167850    Kevin Wachira Njoroge
# 107748                      NaN
# 149485                      NaN
# 219643                      NaN
# 152266                      NaN
# 89745                       NaN
# 209025                      NaN
# 88380                       NaN
# Name: second_person, dtype: object

# %%
df_large_districts['ir_num']=df_large_districts.notice_body.str.extract("I.R. ([\d]+)") 
df_large_districts['ir_num'].sample(12)
#certificate of title registered as I.R. 120880/1,
# Out:
# 97023     NaN
# 7683      NaN
# 49976     NaN
# 84237     NaN
# 203642    NaN
# 86760     NaN
# 218422    NaN
# 164772    NaN
# 16259     NaN
# 80223     NaN
# 77412     NaN
# 8393      NaN
# Name: ir_num, dtype: object

# %%
df_large_districts['days']=df_large_districts.notice_body.str.extract("of [\w]+ [(]([\d]+)[)] days") 
df_large_districts['days'].sample(12)
#of sixty (60) days
# Out:
# 48353     60
# 95065     60
# 175384    60
# 162774    30
# 178976    60
# 80993     60
# 172996    60
# 200492    30
# 86968     30
# 158332    60
# 162020    30
# 181546    60
# Name: days, dtype: object

# %%
df_large_districts['succession']=df_large_districts.notice_body.str.extract("in succession cause No. ([\d]+ of [\d]+)") 
df_large_districts['succession'].sample(12)
#in succession cause No. 93 of 2013 has
# Out:
# 65153     NaN
# 220316    NaN
# 142887    NaN
# 26830     NaN
# 14604     NaN
# 91507     NaN
# 30339     NaN
# 34156     NaN
# 64927     NaN
# 214346    NaN
# 112330    NaN
# 224696    NaN
# Name: succession, dtype: object

# %%
df_large_districts['township']=df_large_districts.notice_body.str.extract("in ([\w ]+) Township") 
df_large_districts['township'].sample(12)
#situate in Gilgil Township in the district of Nakuru
# Out:
# 96740     NaN
# 122796    NaN
# 88029     NaN
# 42374     NaN
# 129556    NaN
# 158200    NaN
# 228186    NaN
# 156465    NaN
# 21494     NaN
# 181449    NaN
# 49758     NaN
# 213888    NaN
# Name: township, dtype: object

# %%
df_large_districts['in_the_district_of']=df_large_districts.notice_body.str.extract("district of ([\w ]+),") 
df_large_districts['in_the_district_of'].sample(12)
#situate in Gilgil Township in the district of Nakuru
# Out:
# 119396          Siaya
# 86715         Nairobi
# 76224          Vihiga
# 27001     Trans Nzoia
# 69518           Nandi
# 86970           Siaya
# 201495         Kisumu
# 22727         Kajiado
# 178343          Busia
# 196989       Kakamega
# 94987          Nakuru
# 37394        Laikipia
# Name: in_the_district_of, dtype: object

# %%
df_large_districts['province_code']=df_large_districts['HASC'].str.extract("[A-Z][A-Z].([A-Z][A-Z]).[A-Z][A-Z]") 
df_large_districts['province_code'].sample(12)
#KE.WE.KK
# Out:
# 183021     EA
# 223909     RV
# 51486      RV
# 102937     CE
# 36798      WE
# 164755     RV
# 22656     NaN
# 190663    NaN
# 47708      RV
# 85874      WE
# 5186      NaN
# 65879      CO
# Name: province_code, dtype: object

# %%
df_large_districts['province_code'].unique()
# Out:
# array(['NA', nan, 'CE', 'EA', 'RV', 'CO', 'NY', 'WE', 'NE'], dtype=object)

# %% [markdown]
# # Reading data on provinces and their codes

# %%
df_provinces=pd.read_excel('/Users/ivynyayieka/Downloads/provinces.xlsx')
df_provinces.head()
# Out:
#         province province_code
# 0        Central            CE
# 1          Coast            CO
# 2        Eastern            EA
# 3        Nairobi           NaN
# 4  North Eastern            NE

# %% [markdown]
# # Merging province data to dataframe

# %%
df_large_provinces = pd.merge(df_large_districts, df_provinces, left_on='province_code', right_on='province_code', how='left')
df_large_provinces.sample(10)
# Out:
#                                                                              key_0  \
# 184393  http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 198124   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 44225   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 43293   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 203828   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEwOQ--/Vol.CXVII-No.1/
# 90456   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Mw--/Vol.CXVII-No.80/
# 126584  http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2OQ--/Vol.CXVII-No.52/
# 73699   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Nw--/Vol.CXVII-No.84/
# 196301   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 190819   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNQ--/Vol.CXVII-No.9/
#
#         index  year                                             url_year  \
# 184393      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 198124      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 44225       4  2014  http://kenyalaw.org/kenya_gazette/gazette/year/2014
# 43293       4  2014  http://kenyalaw.org/kenya_gazette/gazette/year/2014
# 203828      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 90456       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 126584      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 73699       5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 196301      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
# 190819      5  2015  http://kenyalaw.org/kenya_gazette/gazette/year/2015
#
#                                                                      gazette_links  \
# 184393  http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 198124   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 44225   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 43293   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 203828   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEwOQ--/Vol.CXVII-No.1/
# 90456   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Mw--/Vol.CXVII-No.80/
# 126584  http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2OQ--/Vol.CXVII-No.52/
# 73699   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Nw--/Vol.CXVII-No.84/
# 196301   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 190819   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNQ--/Vol.CXVII-No.9/
#
#              volume_num                              volume_date  \
# 184393  Vol.CXVII-No.12   NAIROBI, \n\t\t    \t06 February,2015
# 198124   Vol.CXVII-No.7    NAIROBI, \n\t\t    \t23 January,2015
# 44225   Vol.CXVI-No.110  NAIROBI, \n\t\t    \t12 September,2014
# 43293   Vol.CXVI-No.110  NAIROBI, \n\t\t    \t12 September,2014
# 203828   Vol.CXVII-No.1    NAIROBI, \n\t\t    \t02 January,2015
# 90456   Vol.CXVII-No.80       NAIROBI, \n\t\t    \t31 July,2015
# 126584  Vol.CXVII-No.52        NAIROBI, \n\t\t    \t22 May,2015
# 73699   Vol.CXVII-No.84     NAIROBI, \n\t\t    \t14 August,2015
# 196301   Vol.CXVII-No.7    NAIROBI, \n\t\t    \t23 January,2015
# 190819   Vol.CXVII-No.9    NAIROBI, \n\t\t    \t30 January,2015
#
#                                                                         volume_url  \
# 184393  http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNw--/Vol.CXVII-No.12/
# 198124   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 44225   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 43293   http://kenyalaw.org/kenya_gazette/gazette/volume/MTA3NA--/Vol.CXVI-No.110/
# 203828   http://kenyalaw.org/kenya_gazette/gazette/volume/MTEwOQ--/Vol.CXVII-No.1/
# 90456   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Mw--/Vol.CXVII-No.80/
# 126584  http://kenyalaw.org/kenya_gazette/gazette/volume/MTE2OQ--/Vol.CXVII-No.52/
# 73699   http://kenyalaw.org/kenya_gazette/gazette/volume/MTE5Nw--/Vol.CXVII-No.84/
# 196301   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExMw--/Vol.CXVII-No.7/
# 190819   http://kenyalaw.org/kenya_gazette/gazette/volume/MTExNQ--/Vol.CXVII-No.9/
#
#                 notice_num_title           notice_act_title  notice_num_year  \
# 184393    GAZETTE NOTICE NO. 749  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 198124    Gazette Notice No. 436  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 44225    GAZETTE NOTICE NO. 6331  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 43293    GAZETTE NOTICE NO. 6353  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 203828     Gazette Notice No. 42  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 90456   GAZETTE NOTICE NO.  5569  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 126584   GAZETTE NOTICE NO. 3531  THE LAND REGISTRATION ACT  (No. 3 of 2012)
# 73699    GAZETTE NOTICE NO. 5881  THE LAND REGISTRATION ACT  (No. 3 of 2012)
#
                                                                                                                                                                                                                                                                                                                                                                                                                                                                         WHEREAS Stephen Mwaniki Magethe (ID/5172279), of P.O. Box 233, North Kinangop in the Republic of Kenya, is registered as proprietor in absolute ownership interest of that piece of land containing 0.405 hectare or thereabouts, situate in the district of Nyandarua, registered under title No. Nyandarua/Mkungi/1788, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
# 196301                                                                                                                                                                                                                                                                                                                                                                                                                               WHEREAS (1) Robert Njuguna Njubi and (2) John Njenga Njubi, both of P.O. Box 1244–20117, Naivasha in the Republic of Kenya, are the registered proprietors lessees of all that piece of land known as L.R. No. 1556/39, situate in the south east of Naivasha Town in Nakuru District, by virtue of a certificate of title registered as I.R. 42592/1, and whereas sufficient evidence has been adduced to show that the said certificate of title issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a provisional certificate of title provided that no objection has been received within that period.
# 190819                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  WHEREAS Joseph Mwangi Mbochere, is registered as proprietor in absolute ownership interest of that piece of land containing 3.92 hectares or thereabout, situate in the district of Kirinyaga, registered under title No. Kiine/Thigirichi/369, and whereas sufficient evidence has been adduced to show that the land title deed issued thereof has been lost, notice is given that after the expiration of sixty (60) days from the date hereof, I shall issue a new title deed provided that no objection has been received within that period.
#
#                             notice_date notice_registrar_name  \
# 184393    Dated the 6th February, 2015.        M. V. BUNYOLI,
# 198124    Dated the 23rd January, 2015.         P. K. KIMANI,
# 44225   Dated the 12th September, 2014.       S. N. NDIRANGU,
# 43293   Dated the 12th September, 2014.          C. W. NJAGI,
# 203828     Dated the 2nd January, 2015.          E. A. ODERO,
# 90456        Dated the 31st July, 2015.        G. M. NJOROGE,
# 126584        Dated the 22nd May, 2014.         P. A. OWEYA ,
# 73699      Dated the 14th August, 2015.        J. W. KARANJA,
# 196301    Dated the 23rd January, 2015.         C. N. KITUYI,
# 190819    Dated the 30th January, 2015.         J. K. MUTHEE,
#
#                                                                          notice_num_loc  \
# 184393      MR/6742458                               Land Registrar, Nakuru District.
# 198124          MR/6724403                           Land Registrar, Murang’a District.
# 44225      MR/5748961                                   Land Registrar, Nyeri District.
# 43293          MR/5749040                           Land Registrar, Kirinyaga District.
# 203828       MR/6724114                                 Land Registrar, Nandi District.
# 90456           MR/7796992                           Land Registrar, Machakos District.
# 126584      MR/7413518                                  Land Registrar, Siaya District.
# 73699                   MR/7769841         Land Registrar, Nyandarua/Samburu Districts.
# 196301  MR/6724492                                       Registrar of Titles, Nairobi.
# 190819         MR/6742125                           Land Registrar, Kirinyaga District.
#
#                notice_loc   District      HASC    Cod  Population  Area(km.²)  \
# 184393             Nakuru     Nakuru  KE.RV.NK  709.0   1187039.0      7242.0
# 198124           Murang’a        NaN       NaN    NaN         NaN         NaN
# 44225               Nyeri      Nyeri  KE.CE.NY  205.0    661156.0      3356.0
# 43293           Kirinyaga  Kirinyaga  KE.CE.KY  202.0    457105.0      1478.0
# 203828              Nandi      Nandi  KE.RV.NA  710.0    578751.0      2899.0
# 90456            Machakos   Machakos  KE.EA.MC  405.0    906644.0      6281.0
# 126584              Siaya      Siaya  KE.NY.SI  609.0    480184.0      1520.0
# 73699   Nyandarua/Samburu        NaN       NaN    NaN         NaN         NaN
# 196301            Nairobi    Nairobi  KE.NA.NB  101.0   2143254.0       696.0
# 190819          Kirinyaga  Kirinyaga  KE.CE.KY  202.0    457105.0      1478.0
#
#                Capital      district_named  \
# 184393          Nakuru     Nakuru District
# 198124             NaN                 NaN
# 44225            Nyeri      Nyeri District
# 43293   Kerugoya/Kutus  Kirinyaga District
# 203828        Kapsabet      Nandi District
# 90456         Machakos   Machakos District
# 126584           Siaya      Siaya District
# 73699              NaN                 NaN
# 196301         Nairobi    Nairobi District
# 190819  Kerugoya/Kutus  Kirinyaga District
#
#                                             first_named  acres_hectares  \
# 184393                          Esther Wanjiru Gachuhi              NaN
# 198124                            Julius Kariuki Mwathi             NaN
# 44225                   Patrick Samuel Macharia Gachihi   1.45 hectares
# 43293                             Daniel Gatimu Kalulu              NaN
# 203828                             Wilson Aseka Shahasi             NaN
# 90456                          Michael Kingori Ndirangu  2.075 hectares
# 126584  Wilson Oduor Otieno alias Wilson Oduor Othieno              NaN
# 73699                          Stephen Mwaniki Magethe              NaN
# 196301                                              NaN             NaN
# 190819                           Joseph Mwangi Mbochere   3.92 hectares
#
#                                     title_number  first_ID  \
# 184393    Dundori/Lanet Block 5 (New Gakoe)/2037   2885213
# 198124                                       NaN       NaN
# 44225   Naromoro/Naromoro Block 1/Kieni East/113       NaN
# 43293                         Baragwe/Raimu/1680  13846820
# 203828                         Nandi/Kamobo/1433       NaN
# 90456                   Mavoko/Town Block 3/1203       NaN
# 126584                                       NaN       NaN
# 73699                      Nyandarua/Mkungi/1788   5172279
# 196301                                       NaN       NaN
# 190819                      Kiine/Thigirichi/369       NaN
#
#                   first_address lr_num municipality         second_person  \
# 184393                      NaN    NaN          NaN                   NaN
# 198124      P.O. Box 520, Thika    NaN          NaN                   NaN
# 44225    P.O. Box 377, Naromoro    NaN          NaN                   NaN
# 43293    P.O. Box 113, Kianyaga    NaN          NaN                   NaN
# 203828  P.O. Box 44899, Nairobi    NaN          NaN                   NaN
# 90456     P.O. Box 44334, Karen    NaN          NaN                   NaN
# 126584                      NaN    NaN          NaN  Ellen Adhiambo Oduor
# 73699                       NaN    NaN          NaN                   NaN
# 196301                      NaN    NaN          NaN     John Njenga Njubi
# 190819                      NaN    NaN          NaN                   NaN
#
#        ir_num days succession township in_the_district_of province_code  \
# 184393    NaN   60        NaN      NaN             Nakuru            RV
# 198124    NaN   60        NaN      NaN                NaN           NaN
# 44225     NaN   60        NaN      NaN              Nyeri            CE
# 43293     NaN   60        NaN      NaN          Kirinyaga            CE
# 203828    NaN   60        NaN      NaN              Nandi            RV
# 90456     NaN   60        NaN      NaN           Machakos            EA
# 126584    NaN   30        NaN      NaN              Siaya            NY
# 73699     NaN   60        NaN      NaN          Nyandarua           NaN
# 196301  42592   60        NaN      NaN                NaN            NA
# 190819    NaN   60        NaN      NaN          Kirinyaga            CE
#
#            province
# 184393  Rift Valley
# 198124      Nairobi
# 44225       Central
# 43293       Central
# 203828  Rift Valley
# 90456       Eastern
# 126584       Nyanza
# 73699       Nairobi
# 196301          NaN
# 190819      Central

# %%
df_large_provinces.to_csv('titles_new_df_large_provinces.csv')
